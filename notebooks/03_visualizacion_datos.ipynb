# %% [markdown]
# # Visualización Avanzada de Datos
#
# Este notebook crea visualizaciones avanzadas e interactivas del dataset.
#
# ## Objetivos:
# 1. Gráficos interactivos
# 2. Dashboards
# 3. Análisis visual de relaciones
# 4. Exportación de gráficos

# %%
# Importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

print("✓ Librerías importadas")

# %%
# Cargar datos
df = pd.read_csv('../data/CVD_cleaned.csv')
print(f"Dataset: {df.shape[0]} filas")
